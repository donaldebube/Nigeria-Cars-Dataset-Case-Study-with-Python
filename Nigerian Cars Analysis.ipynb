# %% [markdown]
# # Nigerian Cars Dataset Analysis Case Study Project.
#
# Here, the goal of the project would be **to uncover insights into the car market in Nigeria, such as the most popular car brands, the average price of cars, the fuel efficiency of cars, and the factors that influence car sales in Nigeria.**

# %% [markdown]
# ## Introduction

# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
# Upload the car dataset
naija_cars = pd.read_csv(r"C:\Users\USER\Videos\Data Analytics\Case Studies\Nigeria Cars Dataset Case Study with Python\car_prices.csv")

# %%
# View table 
naija_cars
# Out:
#                         car_id    price fuel type  gear type           Make  \
# 0     icwAaDOmX573WiRRnLFPT237  2812500    Petrol  Automatic         Toyota
# 1     ByZ3NlPy2x0arAIyrKazClUS  5000000    Petrol  Automatic          Acura
# 2     2zG6Mh3kwyoTvWoeKHkV1oFH  7592000    Petrol  Automatic          Acura
# 3     7APLHOPlI93qsYK0ST4D4wB2  9880000    Petrol  Automatic     Land Rover
# 4      zIrIDPJLd46eRQf9JFacc0e  4160000    Petrol  Automatic           Ford
# ...                        ...      ...       ...        ...            ...
# 3717  C4Ly76wwazrtbYRAWkTnv2Q5  1924000    Petrol  Automatic         Toyota
# 3718  jPA7XlJJxdwpZStlurumw59q  1890000    Petrol  Automatic  Mercedes-Benz
# 3719  g5szhuHeXu2djH1Z2be22G7E  1155000    Petrol  Automatic         Toyota
# 3720  mdZMNQK7Zez0cSS67Q9Quhzr  1260000    Petrol  Automatic         Toyota
# 3721  fSUvulLwnXYlc1muFsrjrsAR  1872000    Petrol  Automatic          Honda
#
# ...

# %%
naija_cars.head(10)
# Out:
#                      car_id     price fuel type  gear type           Make  \
# 0  icwAaDOmX573WiRRnLFPT237   2812500    Petrol  Automatic         Toyota
# 1  ByZ3NlPy2x0arAIyrKazClUS   5000000    Petrol  Automatic          Acura
# 2  2zG6Mh3kwyoTvWoeKHkV1oFH   7592000    Petrol  Automatic          Acura
# 3  7APLHOPlI93qsYK0ST4D4wB2   9880000    Petrol  Automatic     Land Rover
# 4   zIrIDPJLd46eRQf9JFacc0e   4160000    Petrol  Automatic           Ford
# 5  cXCDdlfYhkTgnpxVlSqsiBWz   5250000    Petrol  Automatic          Acura
# 6  3Lh1di00mSJudNaHWxOrn1L2  16640000    Petrol  Automatic          Lexus
# 7  7ytxLUCMQ5bWIly5x5EOrMdG   7980000    Petrol  Automatic          Lexus
# 8  fYxBktHsYw4js3ZgJnHwl2zU   3885000    Petrol  Automatic         Toyota
# 9  oGK8lzkToaZZz9BklAkx1ull  13000000    Petrol  Automatic  Mercedes-Benz
#
#          Model  Year of manufacture  Colour      Condition   Mileage  \
# 0      Corolla                 2004  Silver  Nigerian Used  251732.0
# ...

# %%
naija_cars.shape
# Out:
# (3722, 20)

# %% [markdown]
# ## Clean The Dataset
#
# Find all the Null Values in the dataset. If there is any null value in any column, **then fill it with the mean of the column.**

# %% [markdown]
# #### Change Column Names
#
# Here, I will write a code that will give the column names a generic naming structure.

# %% [markdown]
# ##### First of all, get a list of all the columns.

# %%
naija_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3722 entries, 0 to 3721
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_id               3722 non-null   object
#  1   price                3722 non-null   int64
#  2   fuel type            3721 non-null   object
#  3   gear type            3720 non-null   object
#  4   Make                 3722 non-null   object
#  5   Model                3722 non-null   object
#  6   Year of manufacture  3722 non-null   int64
#  7   Colour               3717 non-null   object
#  8   Condition            3722 non-null   object
#  9   Mileage              3663 non-null   float64
#  10  Engine Size          3661 non-null   float64
#  11  Selling Condition    3722 non-null   object
#  12  Bought Condition     3722 non-null   object
#  13  car                  1767 non-null   object
#  14  Trim                 879 non-null    object
# ...

# %% [markdown]
# ##### Now to restructure
#
# Create a temp table to test the code in order to avoid an error occurring

# %%
temp_naija_cars = naija_cars

temp_naija_cars = temp_naija_cars.rename(columns=
    {
        'car_id':'Car ID',
        'price':'Price',
        'fuel type':'Fuel Type',
        'gear type':'Gear Type',
        'car':'Car'
    }
)

temp_naija_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3722 entries, 0 to 3721
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Car ID               3722 non-null   object
#  1   Price                3722 non-null   int64
#  2   Fuel Type            3721 non-null   object
#  3   Gear Type            3720 non-null   object
#  4   Make                 3722 non-null   object
#  5   Model                3722 non-null   object
#  6   Year of manufacture  3722 non-null   int64
#  7   Colour               3717 non-null   object
#  8   Condition            3722 non-null   object
#  9   Mileage              3663 non-null   float64
#  10  Engine Size          3661 non-null   float64
#  11  Selling Condition    3722 non-null   object
#  12  Bought Condition     3722 non-null   object
#  13  Car                  1767 non-null   object
#  14  Trim                 879 non-null    object
# ...

# %% [markdown]
# ##### Now to use the actual table to effect this change

# %%
naija_cars = naija_cars.rename(columns=
    {
        'car_id':'Car ID',
        'price':'Price',
        'fuel type':'Fuel Type',
        'gear type':'Gear Type',
        'car':'Car'
    }
)

naija_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3722 entries, 0 to 3721
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Car ID               3722 non-null   object
#  1   Price                3722 non-null   int64
#  2   Fuel Type            3721 non-null   object
#  3   Gear Type            3720 non-null   object
#  4   Make                 3722 non-null   object
#  5   Model                3722 non-null   object
#  6   Year of manufacture  3722 non-null   int64
#  7   Colour               3717 non-null   object
#  8   Condition            3722 non-null   object
#  9   Mileage              3663 non-null   float64
#  10  Engine Size          3661 non-null   float64
#  11  Selling Condition    3722 non-null   object
#  12  Bought Condition     3722 non-null   object
#  13  Car                  1767 non-null   object
#  14  Trim                 879 non-null    object
# ...

# %%
naija_cars.isnull().sum()
# Out:
# Car ID                    0
# Price                     0
# Fuel Type                 1
# Gear Type                 2
# Make                      0
# Model                     0
# Year of manufacture       0
# Colour                    5
# Condition                 0
# Mileage                  59
# Engine Size              61
# Selling Condition         0
# Bought Condition          0
# Car                    1955
# Trim                   2843
# Drivetrain             2884
# Seats                  2934
# Number of Cylinders    2896
# Horse Power            2967
# Registered city        1821
# dtype: int64

# %% [markdown]
# #### For Fuel Type

# %%
# Fill the empty column with 'Not Provided' of the column

naija_cars['Fuel Type'].fillna("Not Provided", inplace = True)

# %%
# Verify values 
unique_fuel_type = naija_cars['Fuel Type'].unique()

print(unique_fuel_type)
# Out:
# ['Petrol' 'Diesel' 'Hybrid' 'Electric' 'Not Provided']

# %% [markdown]
# #### For Gear Type

# %%
naija_cars.head(4)
# Out:
#                      Car ID    Price Fuel Type  Gear Type        Make  \
# 0  icwAaDOmX573WiRRnLFPT237  2812500    Petrol  Automatic      Toyota
# 1  ByZ3NlPy2x0arAIyrKazClUS  5000000    Petrol  Automatic       Acura
# 2  2zG6Mh3kwyoTvWoeKHkV1oFH  7592000    Petrol  Automatic       Acura
# 3  7APLHOPlI93qsYK0ST4D4wB2  9880000    Petrol  Automatic  Land Rover
#
#          Model  Year of manufacture  Colour      Condition   Mileage  \
# 0      Corolla                 2004  Silver  Nigerian Used  251732.0
# 1          MDX                 2007   Green   Foreign Used  224589.0
# 2           TL                 2012   White   Foreign Used  111334.0
# 3  Range Rover                 2012    Gray  Nigerian Used   72682.0
#
#    Engine Size Selling Condition Bought Condition    Car  \
# 0       1800.0        Registered       Registered    NaN
# 1       3700.0          Imported         Imported    SUV
# 2       3500.0          Imported         Imported  Sedan
# ...

# %%
# Check for the null values

gear_type_null_rows = naija_cars[naija_cars['Gear Type'].isna()]

print(gear_type_null_rows)
# Out:
#                         Car ID    Price     Fuel Type Gear Type     Make  \
# 1863  CroMaP5NDYMGVBrLvPXdOXHu  3360000  Not Provided       NaN    Lexus
# 3276  mQjZDvuV44QoTh8CHEMdZchc  1732500        Petrol       NaN  Peugeot
#
#      Model  Year of manufacture  Colour      Condition  Mileage  Engine Size  \
# 1863    ES                 2007     NaN  Nigerian Used      NaN          NaN
# 3276   407                 2006  Silver  Nigerian Used  76500.0       2000.0
#
#      Selling Condition Bought Condition  Car            Trim   Drivetrain  \
# 1863        Registered       Registered  NaN             NaN          NaN
# 3276        Registered         Imported  NaN  2.0 ST Comfort  Front Wheel
#
#       Seats  Number of Cylinders  Horse Power Registered city
# 1863    NaN                  NaN          NaN           LAGOS
# 3276    5.0                  NaN        136.0          KADUNA

# %%
# Fill the empty column with 'Not Provided' of the column

naija_cars['Gear Type'].fillna("Not Provided", inplace= True)

# %%
# Verify that it has been cleaned
# It has been cleaned.

naija_cars['Gear Type'].isna().sum()
# Out:
# 0

# %%
# Verify if the the values in the column
unique_gear_type = naija_cars['Gear Type'].unique()

print(unique_gear_type)
# Out:
# ['Automatic' 'Manual' 'CVT' 'Not Provided']

# %%
# Verify the number in value
Counter(naija_cars['Gear Type'])
# Out:
# Counter({'Automatic': 3486, 'Manual': 202, 'CVT': 32, 'Not Provided': 2})

# %% [markdown]
# #### For Colour

# %%
# Verify that the items in the column are appropraite for this column
# They are appropraite
unique_car_colour = naija_cars['Colour'].unique()

print(unique_car_colour)
# Out:
# ['Silver' 'Green' 'White' 'Gray' 'Red' 'Gold' 'Black' 'Blue' 'Brown'
#  'Beige' 'Burgandy' 'Purple' 'Pink' 'Off white' 'Teal' 'Ivory' 'Orange'
#  nan 'Yellow']

# %%
# Check for the null values
naija_cars['Colour'].isna().sum()
# Out:
# 5

# %%
# Fill the empty column with 'Not Provided' of the column
naija_cars['Colour'].fillna("Not Provided", inplace= True)

# %%
# Verify that it has been cleaned
# It has been cleaned.

naija_cars['Colour'].isna().sum()
# Out:
# 0

# %%
unique_car_colour = naija_cars['Colour'].unique()

print(unique_car_colour)
# Out:
# ['Silver' 'Green' 'White' 'Gray' 'Red' 'Gold' 'Black' 'Blue' 'Brown'
#  'Beige' 'Burgandy' 'Purple' 'Pink' 'Off white' 'Teal' 'Ivory' 'Orange'
#  'Not Provided' 'Yellow']

# %% [markdown]
# #### For Mileage

# %%
# Check for the null values

naija_cars.head(3)
# Out:
#                      Car ID    Price Fuel Type  Gear Type    Make    Model  \
# 0  icwAaDOmX573WiRRnLFPT237  2812500    Petrol  Automatic  Toyota  Corolla
# 1  ByZ3NlPy2x0arAIyrKazClUS  5000000    Petrol  Automatic   Acura      MDX
# 2  2zG6Mh3kwyoTvWoeKHkV1oFH  7592000    Petrol  Automatic   Acura       TL
#
#    Year of manufacture  Colour      Condition   Mileage  Engine Size  \
# 0                 2004  Silver  Nigerian Used  251732.0       1800.0
# 1                 2007   Green   Foreign Used  224589.0       3700.0
# 2                 2012   White   Foreign Used  111334.0       3500.0
#
#   Selling Condition Bought Condition    Car                           Trim  \
# 0        Registered       Registered    NaN                            NaN
# 1          Imported         Imported    SUV                            NaN
# 2          Imported         Imported  Sedan  SH-AWD Automatic Tech Package
#
#   Drivetrain  Seats  Number of Cylinders  Horse Power Registered city
# ...

# %%
# Check for the null values

naija_cars['Mileage'].isna().sum()
# Out:
# 59

# %%
# Fill the empty column with the mean of the column
naija_cars['Mileage'].fillna(naija_cars['Mileage'].mean(), inplace= True)

# %%
# Verify that it has been cleaned
# It has been cleaned.

naija_cars['Mileage'].isna().sum()
# Out:
# 0

# %%
naija_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3722 entries, 0 to 3721
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Car ID               3722 non-null   object
#  1   Price                3722 non-null   int64
#  2   Fuel Type            3722 non-null   object
#  3   Gear Type            3722 non-null   object
#  4   Make                 3722 non-null   object
#  5   Model                3722 non-null   object
#  6   Year of manufacture  3722 non-null   int64
#  7   Colour               3722 non-null   object
#  8   Condition            3722 non-null   object
#  9   Mileage              3722 non-null   float64
#  10  Engine Size          3661 non-null   float64
#  11  Selling Condition    3722 non-null   object
#  12  Bought Condition     3722 non-null   object
#  13  Car                  1767 non-null   object
#  14  Trim                 879 non-null    object
# ...

# %% [markdown]
# #### For Bought Condition

# %% [markdown]
# ##### Verify the number of bought condition values in the column

# %%
unique_bought_condition = naija_cars['Bought Condition'].unique()

print(unique_bought_condition)
# Out:
# ['Registered' 'Imported' 'Brand new']

# %% [markdown]
# #### For Selling Condition

# %% [markdown]
# ##### Verify the number of selling condition values in the column

# %%
Counter(naija_cars['Selling Condition'])
# Out:
# Counter({'Registered': 2813, 'Imported': 907, 'Brand new': 2})

# %%
unique_selling_condition = naija_cars['Selling Condition'].unique()

print(unique_selling_condition)
# Out:
# ['Registered' 'Imported' 'Brand new']

# %% [markdown]
# #### For Condition

# %% [markdown]
# ##### Verify the number of condition values in the column

# %%
naija_cars.notnull().sum()
# Out:
# Car ID                 3722
# Price                  3722
# Fuel Type              3722
# Gear Type              3722
# Make                   3722
# Model                  3722
# Year of manufacture    3722
# Colour                 3722
# Condition              3722
# Mileage                3722
# Engine Size            3661
# Selling Condition      3722
# Bought Condition       3722
# Car                    1767
# Trim                    879
# Drivetrain              838
# Seats                   788
# Number of Cylinders     826
# Horse Power             755
# Registered city        1901
# dtype: int64

# %%
Counter(naija_cars['Condition'])
# Out:
# Counter({'Nigerian Used': 2813, 'Foreign Used': 907, 'Brand New': 2})

# %%
unique_car_condition = naija_cars['Condition'].unique()

print(unique_car_condition)
# Out:
# ['Nigerian Used' 'Foreign Used' 'Brand New']

# %% [markdown]
# #### For Engine Size

# %%
unique_engine_size = naija_cars['Engine Size'].unique()

print(unique_engine_size)
# Out:
# [1.80e+03 3.70e+03 3.50e+03 4.00e+03 4.80e+03 3.00e+03 2.50e+03 4.20e+03
#  2.80e+03 2.70e+03 3.30e+03 4.90e+03 4.70e+03 2.40e+03 4.60e+03 1.60e+03
#  4.50e+03 2.00e+03 5.70e+03      nan 5.70e+04 3.60e+03 5.50e+03 5.40e+03
#  4.00e+04 5.00e+03 5.80e+03 3.50e+05 3.40e+03 3.20e+03 3.80e+03 4.40e+03
#  1.50e+03 2.30e+03 3.00e+05 5.60e+03 2.50e+04 1.40e+03 2.40e+05 1.80e+05
#  1.30e+03 2.20e+03 2.00e+04 1.80e+04 3.00e+04 2.60e+03 1.20e+03 6.00e+03
#  2.20e+05 2.40e+06 1.40e+04 3.00e+02 1.10e+03 1.60e+05 2.50e+05 1.00e+03
#  1.70e+03 2.00e+02 3.50e+04 5.30e+03 3.50e+06 3.30e+04 6.30e+03 1.80e+02
#  2.70e+05 3.30e+05 3.58e+03 1.80e+06 2.40e+04 2.70e+04]

# %%
# Check if the colum is a numerical column or character column
# It has numerical values

naija_cars.head(5)
# Out:
#                      Car ID    Price Fuel Type  Gear Type        Make  \
# 0  icwAaDOmX573WiRRnLFPT237  2812500    Petrol  Automatic      Toyota
# 1  ByZ3NlPy2x0arAIyrKazClUS  5000000    Petrol  Automatic       Acura
# 2  2zG6Mh3kwyoTvWoeKHkV1oFH  7592000    Petrol  Automatic       Acura
# 3  7APLHOPlI93qsYK0ST4D4wB2  9880000    Petrol  Automatic  Land Rover
# 4   zIrIDPJLd46eRQf9JFacc0e  4160000    Petrol  Automatic        Ford
#
#          Model  Year of manufacture  Colour      Condition   Mileage  \
# 0      Corolla                 2004  Silver  Nigerian Used  251732.0
# 1          MDX                 2007   Green   Foreign Used  224589.0
# 2           TL                 2012   White   Foreign Used  111334.0
# 3  Range Rover                 2012    Gray  Nigerian Used   72682.0
# 4         Edge                 2013    Gray  Nigerian Used   92118.0
#
#    Engine Size Selling Condition Bought Condition    Car  \
# 0       1800.0        Registered       Registered    NaN
# ...

# %%
# Verify the null values in the Engine Size column

naija_cars['Engine Size'].isna().sum()
# Out:
# 61

# %%
# Replace the null values with interpolation method

naija_cars['Engine Size'].interpolate(method='linear', inplace= True)

# Verify that it has been cleaned
# It has been cleaned.
print(naija_cars.isna().sum())
print(naija_cars['Engine Size'].isna().sum())
# Out:
# Car ID                    0
# Price                     0
# Fuel Type                 0
# Gear Type                 0
# Make                      0
# Model                     0
# Year of manufacture       0
# Colour                    0
# Condition                 0
# Mileage                   0
# Engine Size               0
# Selling Condition         0
# Bought Condition          0
# Car                    1955
# Trim                   2843
# Drivetrain             2884
# Seats                  2934
# Number of Cylinders    2896
# Horse Power            2967
# Registered city        1821
# dtype: int64
# 0

# %%
unique_engine_size = naija_cars['Engine Size'].unique()

print(unique_engine_size)
# Out:
# [1.80e+03 3.70e+03 3.50e+03 4.00e+03 4.80e+03 3.00e+03 2.50e+03 4.20e+03
#  2.80e+03 2.70e+03 3.30e+03 4.90e+03 4.70e+03 2.40e+03 4.60e+03 1.60e+03
#  4.50e+03 2.00e+03 5.70e+03 2.45e+03 5.70e+04 3.60e+03 5.50e+03 5.40e+03
#  4.00e+04 5.00e+03 5.80e+03 3.50e+05 3.40e+03 3.20e+03 3.80e+03 3.65e+03
#  2.65e+03 4.40e+03 1.50e+03 2.30e+03 3.00e+05 5.60e+03 2.50e+04 1.40e+03
#  2.40e+05 1.80e+05 1.30e+03 2.20e+03 2.00e+04 1.80e+04 3.00e+04 2.10e+03
#  3.15e+03 2.75e+03 2.60e+03 1.20e+03 6.00e+03 2.20e+05 2.40e+06 2.95e+03
#  2.90e+03 1.40e+04 3.00e+02 1.10e+03 1.60e+05 2.50e+05 1.00e+03 1.70e+03
#  2.35e+03 2.00e+02 1.90e+03 3.50e+04 1.87e+04 2.55e+03 3.90e+03 2.25e+03
#  5.30e+03 3.50e+06 3.30e+04 6.30e+03 1.80e+02 2.70e+05 3.85e+03 3.25e+03
#  4.45e+03 3.30e+05 3.58e+03 1.80e+06 2.40e+04 2.70e+04 3.75e+03]

# %%
Counter(naija_cars['Engine Size'])
# Out:
# Counter({1800.0: 520,
#          3700.0: 50,
#          3500.0: 856,
#          4000.0: 69,
#          4800.0: 8,
#          3000.0: 264,
#          2500.0: 290,
#          4200.0: 4,
#          2800.0: 9,
#          2700.0: 73,
#          3300.0: 140,
#          4900.0: 6,
#          4700.0: 61,
#          2400.0: 536,
#          4600.0: 18,
#          1600.0: 92,
#          4500.0: 9,
#          2000.0: 252,
#          5700.0: 10,
#          2450.0: 6,
#          57000.0: 1,
#          3600.0: 17,
#          5500.0: 11,
#          5400.0: 4,
#          40000.0: 4,
#          5000.0: 13,
#          5800.0: 1,
#          350000.0: 15,
#          3400.0: 16,
#          3200.0: 27,
#          3800.0: 18,
#          3650.0: 2,
#          2650.0: 4,
#          4400.0: 10,
#          1500.0: 21,
#          2300.0: 39,
#          300000.0: 3,
#          5600.0: 16,
#          25000.0: 2,
#          1400.0: 40,
#          240000.0: 12,
#          180000.0: 16,
#          1300.0: 10,
# ...

# %% [markdown]
# #### For Car Type

# %%
naija_cars['Car'].isna().sum()
# Out:
# 1955

# %%
naija_cars['Car'].shape

# Verify if the number of null values is morethan the rows with values
# It is more.
3722 - 1955
# Out:
# 1767

# %%
# Values of all the unique characters in the column
unique_car_types = naija_cars['Car'].unique()
print(unique_car_types)
# Out:
# [nan 'SUV' 'Sedan' 'Truck' 'Crossover' 'Van' 'Bus' 'Coupe' 'Hatchback'
#  'Minivan' 'Pickup' 'Convertible' 'Station Wagon' 'Pick-up Double Cabin'
#  'MUV' 'Saloon']

# %%
# Use the replace value method to clean this column

naija_cars['Car'].fillna("Not Provided", inplace= True)

# Verify if the column has been cleaned
# Yes, it has been cleaned
print(naija_cars.isna().sum())
print(naija_cars['Car'].isna().sum())
# Out:
# Car ID                    0
# Price                     0
# Fuel Type                 0
# Gear Type                 0
# Make                      0
# Model                     0
# Year of manufacture       0
# Colour                    0
# Condition                 0
# Mileage                   0
# Engine Size               0
# Selling Condition         0
# Bought Condition          0
# Car                       0
# Trim                   2843
# Drivetrain             2884
# Seats                  2934
# Number of Cylinders    2896
# Horse Power            2967
# Registered city        1821
# dtype: int64
# 0

# %%
#Verify again if the null values have been removed
unique_car_types = naija_cars['Car'].unique()
print(unique_car_types)
# Out:
# ['Not Provided' 'SUV' 'Sedan' 'Truck' 'Crossover' 'Van' 'Bus' 'Coupe'
#  'Hatchback' 'Minivan' 'Pickup' 'Convertible' 'Station Wagon'
#  'Pick-up Double Cabin' 'MUV' 'Saloon']

# %%
#Verify again if the null values have been removed
print(naija_cars['Car'].isna().sum())
# Out:
# 0

# %% [markdown]
# ##### Inspect the number of columns remaining and the null values present

# %%
naija_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3722 entries, 0 to 3721
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Car ID               3722 non-null   object
#  1   Price                3722 non-null   int64
#  2   Fuel Type            3722 non-null   object
#  3   Gear Type            3722 non-null   object
#  4   Make                 3722 non-null   object
#  5   Model                3722 non-null   object
#  6   Year of manufacture  3722 non-null   int64
#  7   Colour               3722 non-null   object
#  8   Condition            3722 non-null   object
#  9   Mileage              3722 non-null   float64
#  10  Engine Size          3722 non-null   float64
#  11  Selling Condition    3722 non-null   object
#  12  Bought Condition     3722 non-null   object
#  13  Car                  3722 non-null   object
#  14  Trim                 879 non-null    object
# ...

# %% [markdown]
# ##### Drop the following columns due to insufficient values that can affect the analysis

# %%
# Check for the number of null values left in each column
naija_cars.isna().sum()
# Out:
# Car ID                    0
# Price                     0
# Fuel Type                 0
# Gear Type                 0
# Make                      0
# Model                     0
# Year of manufacture       0
# Colour                    0
# Condition                 0
# Mileage                   0
# Engine Size               0
# Selling Condition         0
# Bought Condition          0
# Car                       0
# Trim                   2843
# Drivetrain             2884
# Seats                  2934
# Number of Cylinders    2896
# Horse Power            2967
# Registered city        1821
# dtype: int64

# %%
#Get list of all the columns
naija_cars.columns
# Out:
# Index(['Car ID', 'Price', 'Fuel Type', 'Gear Type', 'Make', 'Model',
#        'Year of manufacture', 'Colour', 'Condition', 'Mileage', 'Engine Size',
#        'Selling Condition', 'Bought Condition', 'Car', 'Trim', 'Drivetrain',
#        'Seats', 'Number of Cylinders', 'Horse Power', 'Registered city'],
#       dtype='object')

# %%
#Drop the following columns due to inssuficient values that can affect the analysis
naija_cars.drop(
    columns=[
        'Trim',
        'Drivetrain',
        'Seats',
        'Number of Cylinders',
        'Horse Power'
    ], axis= 1, inplace=True
)

# %%
# Verify that the columns have been dropped.
naija_cars.isna().sum()
# Out:
# Car ID                    0
# Price                     0
# Fuel Type                 0
# Gear Type                 0
# Make                      0
# Model                     0
# Year of manufacture       0
# Colour                    0
# Condition                 0
# Mileage                   0
# Engine Size               0
# Selling Condition         0
# Bought Condition          0
# Car                       0
# Registered city        1821
# dtype: int64

# %% [markdown]
# #### For Registered City

# %%
# Verify the number of vehicles registered in each city
Counter(naija_cars['Registered city'])
# Out:
# Counter({nan: 1821,
#          'Lagos': 399,
#          'LAGOS': 804,
#          'Abuja': 143,
#          'FCT': 10,
#          'ABUJA': 185,
#          'RIVERS': 39,
#          'EDO': 5,
#          'NASARAWA': 8,
#          'Lagos State': 16,
#          'Plateau': 6,
#          'ASABA': 4,
#          'NASSARAWA': 4,
#          'Osun': 1,
#          'ANAMBRA': 11,
#          'BENIN': 21,
#          'FKJ-880HM': 1,
#          'AKWA IBOM': 17,
#          'Rivers': 25,
#          'KADUNA': 15,
#          'lagos': 28,
#          'IMO': 21,
#          'RIVERS STATE': 9,
#          'OYO': 10,
#          'KWARA': 5,
#          'Delta': 3,
#          'Ondo': 11,
#          'DELTA': 6,
#          'Kaduna': 9,
#          'BAYELSA': 4,
#          'yobe': 2,
#          'ONDO': 2,
#          'BENUE STATE': 2,
#          'Nasarawa': 1,
#          'BENUE': 2,
#          'ABIA': 1,
#          'CROSS RIVER': 1,
#          'Kwara': 2,
#          'sokoto': 1,
#          'Cross River': 1,
# ...

# %%
#Get the unique values of the registered city

unique_registered_city = naija_cars['Registered city'].unique()

print(unique_registered_city)
# Out:
# [nan 'Lagos' 'LAGOS' 'Abuja' 'FCT' 'ABUJA' 'RIVERS' 'EDO' 'NASARAWA'
#  'Lagos State' 'Plateau' 'ASABA' 'NASSARAWA' 'Osun' 'ANAMBRA' 'BENIN'
#  'FKJ-880HM' 'AKWA IBOM' 'Rivers' 'KADUNA' 'lagos' 'IMO' 'RIVERS STATE'
#  'OYO' 'KWARA' 'Delta' 'Ondo' 'DELTA' 'Kaduna' 'BAYELSA' 'yobe' 'ONDO'
#  'BENUE STATE' 'Nasarawa' 'BENUE' 'ABIA' 'CROSS RIVER' 'Kwara' 'sokoto'
#  'Cross River' 'Ogun' 'PLATEAU' 'OSUN' 'OGUN' 'NASARRAWA' 'Sokoto'
#  'Katsina' 'Imo' 'ENUGU' 'Rivers state' 'NIGER' 'KANO' 'Oyo' 'BORNO'
#  'LAGOS STATE' 'Kano State' 'OSUN STATE' 'SEME' 'KOGI' 'ADAMAWA'
#  'Delta state' 'Benue' 'Akwa-Ibom' 'Ekiti' '0' 'ZAMFARA' 'AKURE'
#  'ABEOKUTA' 'Lagso' 'PLATEAU STATE' 'BAUCHI' 'RIVER STATE']

# %%
naija_cars['Registered city'].fillna('Not Provided', inplace=True)

# %%
Counter(naija_cars['Registered city'])
# Out:
# Counter({'Not Provided': 1821,
#          'Lagos': 399,
#          'LAGOS': 804,
#          'Abuja': 143,
#          'FCT': 10,
#          'ABUJA': 185,
#          'RIVERS': 39,
#          'EDO': 5,
#          'NASARAWA': 8,
#          'Lagos State': 16,
#          'Plateau': 6,
#          'ASABA': 4,
#          'NASSARAWA': 4,
#          'Osun': 1,
#          'ANAMBRA': 11,
#          'BENIN': 21,
#          'FKJ-880HM': 1,
#          'AKWA IBOM': 17,
#          'Rivers': 25,
#          'KADUNA': 15,
#          'lagos': 28,
#          'IMO': 21,
#          'RIVERS STATE': 9,
#          'OYO': 10,
#          'KWARA': 5,
#          'Delta': 3,
#          'Ondo': 11,
#          'DELTA': 6,
#          'Kaduna': 9,
#          'BAYELSA': 4,
#          'yobe': 2,
#          'ONDO': 2,
#          'BENUE STATE': 2,
#          'Nasarawa': 1,
#          'BENUE': 2,
#          'ABIA': 1,
#          'CROSS RIVER': 1,
#          'Kwara': 2,
#          'sokoto': 1,
#          'Cross River': 1,
# ...

# %%
## Drop values 0, SEME and FKJ-880HM in the Registered City column
naija_cars = naija_cars[naija_cars['Registered city'] != 'SEME']
naija_cars = naija_cars[naija_cars['Registered city'] != '0']
naija_cars = naija_cars[naija_cars['Registered city'] != 'FKJ-880HM']

# %%
#Verify if FKJ-880HM, SEME and 0 are present in the list
Counter(naija_cars['Registered city'])
# Out:
# Counter({'Not Provided': 1821,
#          'Lagos': 399,
#          'LAGOS': 804,
#          'Abuja': 143,
#          'FCT': 10,
#          'ABUJA': 185,
#          'RIVERS': 39,
#          'EDO': 5,
#          'NASARAWA': 8,
#          'Lagos State': 16,
#          'Plateau': 6,
#          'ASABA': 4,
#          'NASSARAWA': 4,
#          'Osun': 1,
#          'ANAMBRA': 11,
#          'BENIN': 21,
#          'AKWA IBOM': 17,
#          'Rivers': 25,
#          'KADUNA': 15,
#          'lagos': 28,
#          'IMO': 21,
#          'RIVERS STATE': 9,
#          'OYO': 10,
#          'KWARA': 5,
#          'Delta': 3,
#          'Ondo': 11,
#          'DELTA': 6,
#          'Kaduna': 9,
#          'BAYELSA': 4,
#          'yobe': 2,
#          'ONDO': 2,
#          'BENUE STATE': 2,
#          'Nasarawa': 1,
#          'BENUE': 2,
#          'ABIA': 1,
#          'CROSS RIVER': 1,
#          'Kwara': 2,
#          'sokoto': 1,
#          'Cross River': 1,
#          'Ogun': 5,
# ...

# %%
#Replace null values

naija_cars['Registered city'].isna().sum()

naija_cars.fillna({'Registered city' : 'Not Provided'}, inplace= True)

# %%
#Verify that null values have been replaced with "Not Provided"
#They have been replaced

naija_cars['Registered city'].isna().sum()
# Out:
# 0

# %%
# Get the unique values in the Registered City column

unique_registered_city = naija_cars['Registered city'].unique()

# %%
# Arrange values in ascending order

unique_registered_city.sort()

print(unique_registered_city)
# Out:
# ['ABEOKUTA' 'ABIA' 'ABUJA' 'ADAMAWA' 'AKURE' 'AKWA IBOM' 'ANAMBRA' 'ASABA'
#  'Abuja' 'Akwa-Ibom' 'BAUCHI' 'BAYELSA' 'BENIN' 'BENUE' 'BENUE STATE'
#  'BORNO' 'Benue' 'CROSS RIVER' 'Cross River' 'DELTA' 'Delta' 'Delta state'
#  'EDO' 'ENUGU' 'Ekiti' 'FCT' 'IMO' 'Imo' 'KADUNA' 'KANO' 'KOGI' 'KWARA'
#  'Kaduna' 'Kano State' 'Katsina' 'Kwara' 'LAGOS' 'LAGOS STATE' 'Lagos'
#  'Lagos State' 'Lagso' 'NASARAWA' 'NASARRAWA' 'NASSARAWA' 'NIGER'
#  'Nasarawa' 'Not Provided' 'OGUN' 'ONDO' 'OSUN' 'OSUN STATE' 'OYO' 'Ogun'
#  'Ondo' 'Osun' 'Oyo' 'PLATEAU' 'PLATEAU STATE' 'Plateau' 'RIVER STATE'
#  'RIVERS' 'RIVERS STATE' 'Rivers' 'Rivers state' 'Sokoto' 'ZAMFARA'
#  'lagos' 'sokoto' 'yobe']

# %%
# This is to distinguish the different cities by uppercase, lowercase and mixedcase words.

uppercase_registered_city = [word for word in unique_registered_city if word.isupper()]
lowercase_registered_city = [word for word in unique_registered_city if word.islower()]
mixedcase_registered_city = [word for word in unique_registered_city if not word.islower() and not word.isupper()]

print(uppercase_registered_city)
print(lowercase_registered_city)
print(mixedcase_registered_city)
# Out:
# ['ABEOKUTA', 'ABIA', 'ABUJA', 'ADAMAWA', 'AKURE', 'AKWA IBOM', 'ANAMBRA', 'ASABA', 'BAUCHI', 'BAYELSA', 'BENIN', 'BENUE', 'BENUE STATE', 'BORNO', 'CROSS RIVER', 'DELTA', 'EDO', 'ENUGU', 'FCT', 'IMO', 'KADUNA', 'KANO', 'KOGI', 'KWARA', 'LAGOS', 'LAGOS STATE', 'NASARAWA', 'NASARRAWA', 'NASSARAWA', 'NIGER', 'OGUN', 'ONDO', 'OSUN', 'OSUN STATE', 'OYO', 'PLATEAU', 'PLATEAU STATE', 'RIVER STATE', 'RIVERS', 'RIVERS STATE', 'ZAMFARA']
# ['lagos', 'sokoto', 'yobe']
# ['Abuja', 'Akwa-Ibom', 'Benue', 'Cross River', 'Delta', 'Delta state', 'Ekiti', 'Imo', 'Kaduna', 'Kano State', 'Katsina', 'Kwara', 'Lagos', 'Lagos State', 'Lagso', 'Nasarawa', 'Not Provided', 'Ogun', 'Ondo', 'Osun', 'Oyo', 'Plateau', 'Rivers', 'Rivers state', 'Sokoto']

# %%
#Replace the different city names with correct city names

#For States
naija_cars['Registered city'].replace(
    {
        'Abuja':'ABUJA',
        'FCT': 'ABUJA',
        'LAGOS STATE':'LAGOS',
        'Lagos State':'LAGOS',
        'Lagso':'LAGOS',
        'lagos':'LAGOS',
        'Lagos': 'LAGOS',
        'ABEOKUTA' : 'OGUN',
        'Ogun' : 'OGUN',
        'AKURE':'ONDO',
        'Akwa-Ibom':'AKWA IBOM',
        'ASABA':'DELTA',
        'Benue':'BENUE',
        'BENUE STATE':'BENUE',
        'Cross River':'CROSS RIVER',
        'Delta':'DELTA',
        'Delta state':'DELTA',
        'Imo':'IMO',
        'Kaduna':'KADUNA',
        'Kano State':'KANO',
        'Kwara':'KWARA',
        'NASARRAWA':'NASARAWA',
        'NASSARAWA':'NASARAWA',
        'Nasarawa':'NASARAWA',
        'Ogun':'OGUN',
        'Ondo':'ONDO',
        'OSUN STATE':'OSUN',
        'Osun':'OSUN',
        'Oyo':'OYO',
        'Plateau':'PLATEAU',
        'PLATEAU STATE':'PLATEAU',
        'RIVERS STATE':'RIVERS',
        'RIVER STATE':'RIVERS',
        'Rivers':'RIVERS',
        'Rivers state':'RIVERS',
        'Sokoto':'SOKOTO',
        'sokoto':'SOKOTO',
        'yobe':'YOBE',
        'BENIN': 'EDO',
        'Ekiti':'EKITI',
        'Katsina':'KATSINA'
    },inplace= True
)

# %%
#Verify to check that they have been changed
unique_registered_city = naija_cars['Registered city'].unique()

print(unique_registered_city)
# Out:
# ['Not Provided' 'LAGOS' 'ABUJA' 'RIVERS' 'EDO' 'NASARAWA' 'PLATEAU'
#  'DELTA' 'OSUN' 'ANAMBRA' 'AKWA IBOM' 'KADUNA' 'IMO' 'OYO' 'KWARA' 'ONDO'
#  'BAYELSA' 'YOBE' 'BENUE' 'ABIA' 'CROSS RIVER' 'SOKOTO' 'OGUN' 'KATSINA'
#  'ENUGU' 'NIGER' 'KANO' 'BORNO' 'KOGI' 'ADAMAWA' 'EKITI' 'ZAMFARA'
#  'BAUCHI']

# %%
#Verify to check that they have been changed
Counter(naija_cars['Registered city'])
# Out:
# Counter({'Not Provided': 1821,
#          'LAGOS': 1254,
#          'ABUJA': 338,
#          'RIVERS': 75,
#          'EDO': 26,
#          'NASARAWA': 14,
#          'PLATEAU': 11,
#          'DELTA': 14,
#          'OSUN': 8,
#          'ANAMBRA': 11,
#          'AKWA IBOM': 18,
#          'KADUNA': 24,
#          'IMO': 23,
#          'OYO': 11,
#          'KWARA': 7,
#          'ONDO': 14,
#          'BAYELSA': 4,
#          'YOBE': 2,
#          'BENUE': 5,
#          'ABIA': 1,
#          'CROSS RIVER': 2,
#          'SOKOTO': 2,
#          'OGUN': 13,
#          'KATSINA': 1,
#          'ENUGU': 5,
#          'NIGER': 2,
#          'KANO': 5,
#          'BORNO': 1,
#          'KOGI': 1,
#          'ADAMAWA': 1,
#          'EKITI': 1,
#          'ZAMFARA': 1,
#          'BAUCHI': 1})

# %%
#Verify
unique_registered_city.shape
# Out:
# (33,)

# %%
print(unique_registered_city)
# Out:
# ['Not Provided' 'LAGOS' 'ABUJA' 'RIVERS' 'EDO' 'NASARAWA' 'PLATEAU'
#  'DELTA' 'OSUN' 'ANAMBRA' 'AKWA IBOM' 'KADUNA' 'IMO' 'OYO' 'KWARA' 'ONDO'
#  'BAYELSA' 'YOBE' 'BENUE' 'ABIA' 'CROSS RIVER' 'SOKOTO' 'OGUN' 'KATSINA'
#  'ENUGU' 'NIGER' 'KANO' 'BORNO' 'KOGI' 'ADAMAWA' 'EKITI' 'ZAMFARA'
#  'BAUCHI']

# %%
unique_registered_city.sort()

print(unique_registered_city)
# Out:
# ['ABIA' 'ABUJA' 'ADAMAWA' 'AKWA IBOM' 'ANAMBRA' 'BAUCHI' 'BAYELSA' 'BENUE'
#  'BORNO' 'CROSS RIVER' 'DELTA' 'EDO' 'EKITI' 'ENUGU' 'IMO' 'KADUNA' 'KANO'
#  'KATSINA' 'KOGI' 'KWARA' 'LAGOS' 'NASARAWA' 'NIGER' 'Not Provided' 'OGUN'
#  'ONDO' 'OSUN' 'OYO' 'PLATEAU' 'RIVERS' 'SOKOTO' 'YOBE' 'ZAMFARA']

# %%
unique_registered_city.sort()

print(unique_registered_city)
# Out:
# ['ABIA' 'ABUJA' 'ADAMAWA' 'AKWA IBOM' 'ANAMBRA' 'BAUCHI' 'BAYELSA' 'BENUE'
#  'BORNO' 'CROSS RIVER' 'DELTA' 'EDO' 'EKITI' 'ENUGU' 'IMO' 'KADUNA' 'KANO'
#  'KATSINA' 'KOGI' 'KWARA' 'LAGOS' 'NASARAWA' 'NIGER' 'Not Provided' 'OGUN'
#  'ONDO' 'OSUN' 'OYO' 'PLATEAU' 'RIVERS' 'SOKOTO' 'YOBE' 'ZAMFARA']

# %%
#Verify the number of columns and verify if there are any null values left
naija_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3717 entries, 0 to 3721
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Car ID               3717 non-null   object
#  1   Price                3717 non-null   int64
#  2   Fuel Type            3717 non-null   object
#  3   Gear Type            3717 non-null   object
#  4   Make                 3717 non-null   object
#  5   Model                3717 non-null   object
#  6   Year of manufacture  3717 non-null   int64
#  7   Colour               3717 non-null   object
#  8   Condition            3717 non-null   object
#  9   Mileage              3717 non-null   float64
#  10  Engine Size          3717 non-null   float64
#  11  Selling Condition    3717 non-null   object
#  12  Bought Condition     3717 non-null   object
#  13  Car                  3717 non-null   object
#  14  Registered city      3717 non-null   object
# ...

# %% [markdown]
# #### For Make

# %% [markdown]
# ##### Get a list of all the different car makes and locate the different types that should not be there.
#
# **Note:** The following 'make' in the lsit below should not be there.
# - Seat
# - Other
# - Self Contained
# - Swipe Key Cards

# %%
unique_car_make = naija_cars['Make'].unique()
unique_car_make.sort()

print(unique_car_make)
# Out:
# ['Acura' 'Audi' 'BMW' 'Bentley' 'Buick' 'Cadillac' 'Chevrolet' 'Chrysler'
#  'Citroen' 'Dacia' 'Dodge' 'Ford' 'GAC' 'GMC' 'Honda' 'Hyundai' 'Infiniti'
#  'Iveco' 'JAC' 'Jaguar' 'Jeep' 'Kia' 'Lancia' 'Land Rover' 'Lexus'
#  'Lincoln' 'Mazda' 'Mercedes-Benz' 'Mercury' 'Mini' 'Mitsubishi' 'Nissan'
#  'Opel' 'Other' 'Peugeot' 'Pontiac' 'Porsche' 'Renault' 'Rover' 'Saturn'
#  'Scion' 'Seat' 'Self Contained' 'SsangYong' 'Subaru' 'Suzuki'
#  'Swipe Key Cards' 'Toyota' 'Volkswagen' 'Volvo']

# %% [markdown]
# ##### Verify the numbers each for the different makes

# %%
Counter(naija_cars['Make'])
# Out:
# Counter({'Toyota': 1598,
#          'Acura': 80,
#          'Land Rover': 44,
#          'Ford': 156,
#          'Lexus': 350,
#          'Mercedes-Benz': 294,
#          'Lancia': 1,
#          'Renault': 4,
#          'Hyundai': 154,
#          'Saturn': 2,
#          'Dodge': 17,
#          'Infiniti': 32,
#          'Pontiac': 19,
#          'Cadillac': 4,
#          'Mitsubishi': 33,
#          'Kia': 85,
#          'Jeep': 12,
#          'Honda': 362,
#          'Mini': 5,
#          'Mazda': 56,
#          'Scion': 3,
#          'Nissan': 134,
#          'Chevrolet': 13,
#          'Citroen': 3,
#          'GAC': 1,
#          'Opel': 7,
#          'BMW': 55,
#          'Volkswagen': 71,
#          'Peugeot': 52,
#          'Volvo': 9,
#          'Subaru': 4,
#          'Chrysler': 11,
#          'GMC': 3,
#          'Audi': 18,
#          'Bentley': 1,
#          'Porsche': 4,
#          'Suzuki': 1,
#          'Rover': 3,
#          'Dacia': 1,
#          'Other': 1,
# ...

# %% [markdown]
# ##### As suspected, they all have just one item each.
#
# **Proceed to take them out of the list so that they will not affect the analysis**

# %%
naija_cars = naija_cars[naija_cars['Make'] != 'Seat']
naija_cars = naija_cars[naija_cars['Make'] != 'Other']
naija_cars = naija_cars[naija_cars['Make'] != 'Self Contained']
naija_cars = naija_cars[naija_cars['Make'] != 'Swipe Key Cards']

# %% [markdown]
# **Verify if they have been deleted**
#
# They have been deleted

# %%
unique_car_make = naija_cars['Make'].unique()

print(unique_car_make)
# Out:
# ['Toyota' 'Acura' 'Land Rover' 'Ford' 'Lexus' 'Mercedes-Benz' 'Lancia'
#  'Renault' 'Hyundai' 'Saturn' 'Dodge' 'Infiniti' 'Pontiac' 'Cadillac'
#  'Mitsubishi' 'Kia' 'Jeep' 'Honda' 'Mini' 'Mazda' 'Scion' 'Nissan'
#  'Chevrolet' 'Citroen' 'GAC' 'Opel' 'BMW' 'Volkswagen' 'Peugeot' 'Volvo'
#  'Subaru' 'Chrysler' 'GMC' 'Audi' 'Bentley' 'Porsche' 'Suzuki' 'Rover'
#  'Dacia' 'Mercury' 'Iveco' 'Lincoln' 'SsangYong' 'Jaguar' 'Buick' 'JAC']

# %% [markdown]
# #### For Model
#
# Check for Null values

# %% [markdown]
# ##### Checking for null values
#
# No null value found in the array

# %%
unique_car_model = naija_cars['Model'].unique()

print(unique_car_model)
# Out:
# ['Corolla' 'MDX' 'TL' 'Range Rover' 'Edge' 'ZDX' 'GX' 'GS' 'Camry'
#  'GLK-Class' 'M Class' 'GL-Class' 'Range Rover Vogue' 'Thesis' 'HiAce'
#  'ES' 'Highlander' 'RX 400h' 'Tacoma' 'RAV4' 'Venza' 'Duster' 'Hilux'
#  'Viano' 'Creta' 'H1' 'Santa Fe' 'Range Rover Evoque' 'IS' 'RC' 'Sonata'
#  'C300' 'Sequoia' 'Land Cruiser Prado' 'C-Class' 'Sienna' 'Tundra'
#  'Avalon' 'Vue' 'GLA 250' 'C350' 'Explorer' 'Matrix' 'Sport Trac'
#  'Land Cruiser' 'RX 350' 'GLE-Class' 'CLS' 'Expedition' 'R-Class'
#  'Discovery' 'Corolla Altis' 'Dakota' 'Journey' 'E550' 'Fortuner' 'Azera'
#  'QX60' 'Vibe' 'Elantra' 'F-150' '4-Runner' 'LX' 'Caravan' 'SRX' 'RX'
#  'RDX' 'S-Class' 'E350' 'Solara' 'Pajero' 'Sorento' 'Sedona' 'Wrangler'
#  'Solstice' 'Accord' 'Pilot' 'Escape' 'Prius' 'Ranger' 'Cooper' 'Mustang'
#  'RX 330' 'Mohave' 'Caliber' 'Montero' 'Lr3' 'Accord Crosstour'
#  'CLA-Class' 'Avanza' 'Forte' 'CX-7' 'xB' 'Ridgeline' 'Odyssey' 'Maxima'
# ...

# %%
unique_car_model.sort()

print(unique_car_model)
# Out:
# ['116i' '130i' '200' '206' '230E' '3' '3 Series' '300C' '307' '308' '320i'
#  '323i' '325i' '328i' '4-Runner' '406' '407' '408' '5' '5 Series' '508'
#  '523i' '525i' '528i' '530i' '535i' '550i' '6' '607' '7 Series' '807'
#  'A-Class' 'A4' 'A6' 'A7' 'Acadia' 'Accent' 'Accord' 'Accord Crosstour'
#  'Almera' 'Altima' 'Armada' 'Astra' 'Avalanche' 'Avalon' 'Avanza'
#  'Avenger' 'Avensis' 'Avensis Verso' 'Azera' 'Berlingo' 'Bora' 'Borrego'
#  'C-Class' 'C180' 'C200' 'C220' 'C230' 'C240' 'C250' 'C280' 'C300' 'C320'
#  'C350' 'C4' 'C43' 'CC' 'CL' 'CLA-Class' 'CLS' 'CR-V' 'CX-7' 'CX-9'
#  'Cadenza' 'Caliber' 'Camaro' 'Camry' 'Canter' 'Caravan' 'Carens'
#  'Carina E' 'Cayenne' 'Cerato' 'Challenger' 'Charger' 'Cherokee' 'Citi'
#  'City' 'Civic' 'Commander' 'Compass' 'Condor' 'Continental' 'Cooper'
#  'Corolla' 'Corolla Altis' 'Corolla Verso' 'Creta' 'Crossfire' 'Crosstour'
#  'Daily' 'Dakota' 'Discovery' 'Durango' 'Duster' 'E-350' 'E200' 'E300'
# ...

# %%
naija_cars.head(3)
# Out:
#                      Car ID    Price Fuel Type  Gear Type    Make    Model  \
# 0  icwAaDOmX573WiRRnLFPT237  2812500    Petrol  Automatic  Toyota  Corolla
# 1  ByZ3NlPy2x0arAIyrKazClUS  5000000    Petrol  Automatic   Acura      MDX
# 2  2zG6Mh3kwyoTvWoeKHkV1oFH  7592000    Petrol  Automatic   Acura       TL
#
#    Year of manufacture  Colour      Condition   Mileage  Engine Size  \
# 0                 2004  Silver  Nigerian Used  251732.0       1800.0
# 1                 2007   Green   Foreign Used  224589.0       3700.0
# 2                 2012   White   Foreign Used  111334.0       3500.0
#
#   Selling Condition Bought Condition           Car Registered city
# 0        Registered       Registered  Not Provided    Not Provided
# 1          Imported         Imported           SUV    Not Provided
# 2          Imported         Imported         Sedan    Not Provided

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### For Price Distribution of Different Car Makes
#
# Here, I would like to analyse the list of cars that are the most expensive and the least expensive with their makes and models.

# %%
#To get the columns for this particular insisght
naija_cars[
    {
        'Make', 
        'Model',
        'Price',
        'Year of manufacture'
    }
].head(10)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2040\3546839611.py:2: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   naija_cars[
#          Model  Year of manufacture     Price           Make
# 0      Corolla                 2004   2812500         Toyota
# 1          MDX                 2007   5000000          Acura
# 2           TL                 2012   7592000          Acura
# 3  Range Rover                 2012   9880000     Land Rover
# 4         Edge                 2013   4160000           Ford
# 5          ZDX                 2010   5250000          Acura
# 6           GX                 2011  16640000          Lexus
# 7           GS                 2013   7980000          Lexus
# 8        Camry                 2007   3885000         Toyota
# 9    GLK-Class                 2015  13000000  Mercedes-Benz

# %%
for_price_variation = naija_cars[
    {
        'Make',
        'Model',
        'Price',
        'Year of manufacture',
        'Condition'
        
    }
]
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2040\3796853536.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   for_price_variation = naija_cars[

# %% [markdown]
# ##### To get the most expensive cars

# %%
max_for_price_variation = pd.DataFrame(for_price_variation)
max_for_price_variation.sort_values('Price', ascending=False, inplace=True)

max_for_price_variation.head(20)
# Out:
#       Year of manufacture     Price           Make               Model  \
# 310                  2015  62400000  Mercedes-Benz             S-Class
# 1667                 2015  61875000  Mercedes-Benz             G-Class
# 2070                 2018  50400000         Toyota        Land Cruiser
# 1877                 2020  50400000     Land Rover   Range Rover Velar
# 1892                 2014  49920000  Mercedes-Benz             G-Class
# 2270                 2019  48510000          Lexus                  LX
# 3162                 2018  40950000          Rover                Land
# 1886                 2020  40250000  Mercedes-Benz                 C43
# 23                   2016  39900000     Land Rover         Range Rover
# 1777                 2015  36170000           Ford               F-150
# 2759                 2018  35360000         Toyota  Land Cruiser Prado
# 1521                 2017  33600000     Land Rover           Discovery
# ...

# %% [markdown]
# ##### To get the least expensive cars

# %%
min_for_price_variation = pd.DataFrame(for_price_variation)
min_for_price_variation.sort_values('Price', ascending=True, inplace=True)

min_for_price_variation
# Out:
#       Year of manufacture     Price           Make              Model  \
# 1661                 2000    550000          Honda              Civic
# 1694                 1996    630000     Volkswagen              Vento
# 1677                 1996    630000     Volkswagen              Vento
# 1681                 1995    682500          Honda             Accord
# 1691                 1995    682500          Honda             Accord
# ...                   ...       ...            ...                ...
# 1892                 2014  49920000  Mercedes-Benz            G-Class
# 1877                 2020  50400000     Land Rover  Range Rover Velar
# 2070                 2018  50400000         Toyota       Land Cruiser
# 1667                 2015  61875000  Mercedes-Benz            G-Class
# 310                  2015  62400000  Mercedes-Benz            S-Class
#
#           Condition
# 1661  Nigerian Used
# 1694  Nigerian Used
# 1677  Nigerian Used
# 1681  Nigerian Used
# ...

# %% [markdown]
# ### For Fuel Type and  of Different Car Makes
#
# Here, I aim to find the relationship between fuel types of the different cars with their individual prices.
#
# Questions:
# - What fuel type is used the most?
# - What make of vehicles use the most utilised fuel types?

# %% [markdown]
# ##### Identify the different fuel types present in the dataset

# %%
unique_fuel_type = naija_cars['Fuel Type'].unique()

print(unique_fuel_type)
# Out:
# ['Petrol' 'Diesel' 'Hybrid' 'Electric' 'Not Provided']

# %%
naija_cars[
    {
        'Make',
        'Model',
        'Fuel Type'
    }
]
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2040\2400500977.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   naija_cars[
#      Fuel Type        Model           Make
# 0       Petrol      Corolla         Toyota
# 1       Petrol          MDX          Acura
# 2       Petrol           TL          Acura
# 3       Petrol  Range Rover     Land Rover
# 4       Petrol         Edge           Ford
# ...        ...          ...            ...
# 3717    Petrol         RAV4         Toyota
# 3718    Petrol      M Class  Mercedes-Benz
# 3719    Petrol        Camry         Toyota
# 3720    Petrol         RAV4         Toyota
# 3721    Petrol        Civic          Honda
#
# [3713 rows x 3 columns]

# %% [markdown]
# ##### Most used fuel type
# It shows that petrol is the most used fuel type in the dataset

# %%
Counter(naija_cars['Fuel Type'])
# Out:
# Counter({'Petrol': 3661,
#          'Diesel': 14,
#          'Hybrid': 36,
#          'Electric': 1,
#          'Not Provided': 1})

# %% [markdown]
# **Convert to table format**

# %%
# create a Counter object of the fuel types
fuel_counts = Counter(naija_cars['Fuel Type'])

# convert the Counter object to a pandas DataFrame
fuel_type = pd.DataFrame.from_dict(fuel_counts, orient='index', columns=['Count'])

# sort the DataFrame by the count of each fuel type
fuel_type = fuel_type.sort_values(by='Count', ascending=False)

# reset the index to make the fuel types a column
fuel_type = fuel_type.reset_index().rename(columns={'index': 'Fuel Type'})

# display the resulting table
print(fuel_type)
# Out:
#       Fuel Type  Count
# 0        Petrol   3661
# 1        Hybrid     36
# 2        Diesel     14
# 3      Electric      1
# 4  Not Provided      1

# %% [markdown]
# ##### Total number of cars present in the dataset

# %%
unique_car_make.shape
# Out:
# (46,)

# %% [markdown]
# ##### This is to filter for only cars that use "Petrol"

# %%
fuel_type_petrol = naija_cars[naija_cars['Fuel Type'] == 'Petrol']

# %%
#Verify
fuel_type_petrol
# Out:
#                         Car ID    Price Fuel Type  Gear Type           Make  \
# 0     icwAaDOmX573WiRRnLFPT237  2812500    Petrol  Automatic         Toyota
# 1     ByZ3NlPy2x0arAIyrKazClUS  5000000    Petrol  Automatic          Acura
# 2     2zG6Mh3kwyoTvWoeKHkV1oFH  7592000    Petrol  Automatic          Acura
# 3     7APLHOPlI93qsYK0ST4D4wB2  9880000    Petrol  Automatic     Land Rover
# 4      zIrIDPJLd46eRQf9JFacc0e  4160000    Petrol  Automatic           Ford
# ...                        ...      ...       ...        ...            ...
# 3717  C4Ly76wwazrtbYRAWkTnv2Q5  1924000    Petrol  Automatic         Toyota
# 3718  jPA7XlJJxdwpZStlurumw59q  1890000    Petrol  Automatic  Mercedes-Benz
# 3719  g5szhuHeXu2djH1Z2be22G7E  1155000    Petrol  Automatic         Toyota
# 3720  mdZMNQK7Zez0cSS67Q9Quhzr  1260000    Petrol  Automatic         Toyota
# 3721  fSUvulLwnXYlc1muFsrjrsAR  1872000    Petrol  Automatic          Honda
#
# ...

# %% [markdown]
# ##### Get a list of all car makes that use 'Petrol'

# %%
unique_fuel_type_petrol_make = fuel_type_petrol['Make'].unique()

print(unique_fuel_type_petrol_make)
# Out:
# ['Toyota' 'Acura' 'Land Rover' 'Ford' 'Lexus' 'Mercedes-Benz' 'Renault'
#  'Hyundai' 'Saturn' 'Dodge' 'Infiniti' 'Pontiac' 'Cadillac' 'Mitsubishi'
#  'Kia' 'Jeep' 'Honda' 'Mini' 'Mazda' 'Scion' 'Nissan' 'Chevrolet'
#  'Citroen' 'GAC' 'Opel' 'BMW' 'Volkswagen' 'Peugeot' 'Volvo' 'Subaru'
#  'Chrysler' 'GMC' 'Audi' 'Bentley' 'Porsche' 'Suzuki' 'Rover' 'Dacia'
#  'Mercury' 'Lincoln' 'SsangYong' 'Jaguar' 'Buick' 'JAC']

# %% [markdown]
# ##### This is to arrange the list in alphabetical/ascending order

# %%
unique_fuel_type_petrol_make.sort()

print(unique_fuel_type_petrol_make)
# Out:
# ['Acura' 'Audi' 'BMW' 'Bentley' 'Buick' 'Cadillac' 'Chevrolet' 'Chrysler'
#  'Citroen' 'Dacia' 'Dodge' 'Ford' 'GAC' 'GMC' 'Honda' 'Hyundai' 'Infiniti'
#  'JAC' 'Jaguar' 'Jeep' 'Kia' 'Land Rover' 'Lexus' 'Lincoln' 'Mazda'
#  'Mercedes-Benz' 'Mercury' 'Mini' 'Mitsubishi' 'Nissan' 'Opel' 'Peugeot'
#  'Pontiac' 'Porsche' 'Renault' 'Rover' 'Saturn' 'Scion' 'SsangYong'
#  'Subaru' 'Suzuki' 'Toyota' 'Volkswagen' 'Volvo']

# %% [markdown]
# ##### This is to get the number of each vehicle make and model that uses petrol

# %%
count_petrol_make = fuel_type_petrol[
    {
        'Make', 
        'Model'
    }
].value_counts()

print(count_petrol_make.head(20))
# Out:
# Model       Make
# Camry       Toyota           528
# Corolla     Toyota           404
# Accord      Honda            177
# Highlander  Toyota           136
# ES          Lexus            114
# Sienna      Toyota           103
# RAV4        Toyota            90
# Edge        Ford              77
# RX 350      Lexus             70
# Pilot       Honda             53
# M Class     Mercedes-Benz     51
# MDX         Acura             50
# Venza       Toyota            50
# C300        Mercedes-Benz     48
# Sonata      Hyundai           47
# Avalon      Toyota            47
# Matrix      Toyota            44
# IS          Lexus             41
# CR-V        Honda             38
# Civic       Honda             35
# dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_2040\4097559626.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   count_petrol_make = fuel_type_petrol[

# %% [markdown]
# ##### This is to filter for only cars that use "Diesel"

# %%
fuel_type_diesel = naija_cars[naija_cars['Fuel Type'] == 'Diesel']

# %%
# Verify
fuel_type_diesel
# Out:
#                         Car ID     Price Fuel Type  Gear Type           Make  \
# 14    aa8nq9ZiuiVXOMzlxJvdOPUK   3990000    Diesel     Manual         Lancia
# 2289  tPqVwLhxAs5ikVHkJE5Uno3h   7245000    Diesel     Manual     Mitsubishi
# 2548  gtLfDO2xJXlOBIO2LkTTlZ2i   3275000    Diesel     Manual          Iveco
# 2564  v2PwZDoz3xtHmgKmXdmkdgQJ   4830000    Diesel  Automatic           Ford
# 2589  v2PwZDoz3xtHmgKmXdmkdgQJ   4830000    Diesel  Automatic           Ford
# 2886  u4sE9auH7LGCYr4ZEPDBCTdC   3900000    Diesel     Manual        Hyundai
# 2900  uObpX2nWuIRQd3yjoWEWhq43  10920000    Diesel     Manual         Toyota
# 2904  qhfku5wfHHi4g5cJdcTzAw8c   2625000    Diesel     Manual         Toyota
# 3061  BUqA8LJUYT58cOikNCkRDtCv   2625000    Diesel     Manual     Volkswagen
# 3068  BUqA8LJUYT58cOikNCkRDtCv   2625000    Diesel     Manual     Volkswagen
# 3117  wnUYHJ8QVOfNq5X9jyEcS5wH  26250000    Diesel  Automatic         Toyota
# ...

# %% [markdown]
# ##### Get a list of all car makes that use 'Diesel'

# %%
unique_fuel_type_diesel_make = fuel_type_diesel['Make'].unique()

print(unique_fuel_type_diesel_make)
# Out:
# ['Lancia' 'Mitsubishi' 'Iveco' 'Ford' 'Hyundai' 'Toyota' 'Volkswagen'
#  'Mercedes-Benz']

# %% [markdown]
# ##### This is to get the number of each vehicle make and model that uses diesel

# %%
count_diesel_make = fuel_type_diesel[
    {
        'Make', 
        'Model'
    }
].value_counts()

print(count_diesel_make)
# Out:
# Model               Make
# E-350               Ford             2
# Hilux               Toyota           2
# M Class             Mercedes-Benz    2
# Transporter         Volkswagen       2
# Canter              Mitsubishi       1
# Condor              Toyota           1
# Daily               Iveco            1
# H1                  Hyundai          1
# Land Cruiser Prado  Toyota           1
# Thesis              Lancia           1
# dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_2040\3171740383.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   count_diesel_make = fuel_type_diesel[

# %% [markdown]
# ##### This is to filter for only cars that use "Hybrid"

# %%
fuel_type_hybrid = naija_cars[naija_cars['Fuel Type'] == 'Hybrid']

# %%
#Verify
fuel_type_hybrid
# Out:
#                         Car ID     Price Fuel Type  Gear Type    Make  \
# 24    BzvzeohSLKA2PjywTtWyVWWa   4725000    Hybrid  Automatic   Lexus
# 95    zdIt2DF41eAFHcHs71q1wqY1   5670000    Hybrid  Automatic   Lexus
# 100   box9ZCTWi9lT9ZbeN8Bptwao   5460000    Hybrid  Automatic  Toyota
# 159   eMx5cK6MCefmPvgV4PHTmen0   4368000    Hybrid  Automatic  Toyota
# 185   kSVGq6E4UqCNuiATtX9v2mg3   6825000    Hybrid        CVT  Toyota
# 206   mFpmruVQoh6FprRNbeQ53EzE   3432000    Hybrid  Automatic  Toyota
# 280   3PP4B7NW8oaR3G56ZIavZd4s   3675000    Hybrid        CVT   Lexus
# 336   cWHGtPlNjGp3omd6NR6clFpz   4200000    Hybrid  Automatic   Lexus
# 362   u5zYq6UspPgBjveG9UFX11QK   5250000    Hybrid  Automatic  Toyota
# 405   ySkIQnPTfE92dEUmZvuaT9qM   3150000    Hybrid  Automatic  Toyota
# 456   ySkIQnPTfE92dEUmZvuaT9qM   3150000    Hybrid  Automatic  Toyota
# 519   kkGVPpwuXxkVGXBrnUUcX8rR   3150000    Hybrid        CVT  Toyota
# ...

# %% [markdown]
# ##### Get a list of all car makes that use 'Hybrid'

# %%
unique_fuel_type_hybrid_make = fuel_type_hybrid['Make'].unique()

print(unique_fuel_type_hybrid_make)
# Out:
# ['Lexus' 'Toyota' 'Honda']

# %% [markdown]
# ##### This is to get the number of each vehicle make and model that uses hybrid

# %%
count_hybrid_make = fuel_type_hybrid[
    {
        'Make', 
        'Model'
    }
].value_counts()

print(count_hybrid_make)
# Out:
# Model       Make
# Camry       Toyota    20
# RX 400h     Lexus      7
# Highlander  Toyota     3
# Civic       Honda      2
# Prius       Toyota     2
# Accord      Honda      1
# RX          Lexus      1
# dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_2040\3629088495.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   count_hybrid_make = fuel_type_hybrid[

# %% [markdown]
# ##### This is to filter for only cars that use "Electric"

# %%
fuel_type_electric = naija_cars[naija_cars['Fuel Type'] == 'Electric']

# %%
#Verify
fuel_type_electric
# Out:
#                        Car ID    Price Fuel Type  Gear Type    Make    Model  \
# 241  5XWJfMorjmlK62gDRfWgcVmh  5932000  Electric  Automatic  Toyota  Corolla
#
#      Year of manufacture  Colour      Condition  Mileage  Engine Size  \
# 241                 2016  Silver  Nigerian Used  58667.0       1800.0
#
#     Selling Condition Bought Condition           Car Registered city
# 241        Registered         Imported  Not Provided    Not Provided

# %% [markdown]
# ##### This is to get the number of each vehicle make and model that uses electric

# %%
count_electric_make = fuel_type_electric[
    {
        'Make', 
        'Model'
    }
].value_counts()

print(count_electric_make)
# Out:
# Model    Make
# Corolla  Toyota    1
# dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_2040\1370147779.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   count_electric_make = fuel_type_electric[

# %%
naija_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3713 entries, 0 to 3721
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Car ID               3713 non-null   object
#  1   Price                3713 non-null   int64
#  2   Fuel Type            3713 non-null   object
#  3   Gear Type            3713 non-null   object
#  4   Make                 3713 non-null   object
#  5   Model                3713 non-null   object
#  6   Year of manufacture  3713 non-null   int64
#  7   Colour               3713 non-null   object
#  8   Condition            3713 non-null   object
#  9   Mileage              3713 non-null   float64
#  10  Engine Size          3713 non-null   float64
#  11  Selling Condition    3713 non-null   object
#  12  Bought Condition     3713 non-null   object
#  13  Car                  3713 non-null   object
#  14  Registered city      3713 non-null   object
# ...

# %% [markdown]
# ### For Gear Type
#
# Here, I aim at providing insights on the following:
# - The ratio of automatic, manual and CVT vehicles.
# - The make of vehicles with the highest and lowest number of automatic, manual and CVT vehicles in the dataset
# - The registered city that has the most and least automatic, manual and CVT cars.

# %% [markdown]
# #### Ratio of the different Gear Types
#
# Here, it shows that Automatic vehicles are more in the dataset with 3479

# %%
Gear_type = Counter(naija_cars['Gear Type'])

print(Gear_type)
# Out:
# Counter({'Automatic': 3479, 'Manual': 200, 'CVT': 32, 'Not Provided': 2})

# %%
Counter(naija_cars['Gear Type'])
# Out:
# Counter({'Automatic': 3479, 'Manual': 200, 'CVT': 32, 'Not Provided': 2})

# %% [markdown]
# #### Vehicles that use Automatic, Manual and CVT
#
# Here, I aim to find the highest and lowest number of cars in each of these gear types.

# %% [markdown]
# ##### This is to filter for only cars that use "Automatic" gear type

# %%
gear_type_automatic = naija_cars[naija_cars['Gear Type'] == 'Automatic']

print(gear_type_automatic)
# Out:
#                         Car ID    Price Fuel Type  Gear Type           Make  \
# 0     icwAaDOmX573WiRRnLFPT237  2812500    Petrol  Automatic         Toyota
# 1     ByZ3NlPy2x0arAIyrKazClUS  5000000    Petrol  Automatic          Acura
# 2     2zG6Mh3kwyoTvWoeKHkV1oFH  7592000    Petrol  Automatic          Acura
# 3     7APLHOPlI93qsYK0ST4D4wB2  9880000    Petrol  Automatic     Land Rover
# 4      zIrIDPJLd46eRQf9JFacc0e  4160000    Petrol  Automatic           Ford
# ...                        ...      ...       ...        ...            ...
# 3717  C4Ly76wwazrtbYRAWkTnv2Q5  1924000    Petrol  Automatic         Toyota
# 3718  jPA7XlJJxdwpZStlurumw59q  1890000    Petrol  Automatic  Mercedes-Benz
# 3719  g5szhuHeXu2djH1Z2be22G7E  1155000    Petrol  Automatic         Toyota
# 3720  mdZMNQK7Zez0cSS67Q9Quhzr  1260000    Petrol  Automatic         Toyota
# 3721  fSUvulLwnXYlc1muFsrjrsAR  1872000    Petrol  Automatic          Honda
#
# ...

# %% [markdown]
# ##### This is to get the number of each vehicle make and model that uses automatic gear type

# %%
count_automatic_gear_type = gear_type_automatic[
    {
        'Make',
        'Model',
        'Year of manufacture'
    }
].value_counts()

print(count_automatic_gear_type.head(20))
# Out:
# Model    Year of manufacture  Make
# Camry    2007                 Toyota    99
#          2009                 Toyota    52
# Corolla  2010                 Toyota    50
# Camry    2012                 Toyota    49
# Corolla  2009                 Toyota    49
# Camry    2011                 Toyota    42
#          2008                 Toyota    42
# Corolla  2004                 Toyota    41
# Accord   2008                 Honda     40
# Camry    2010                 Toyota    39
#          2005                 Toyota    38
# Corolla  2006                 Toyota    38
#          2005                 Toyota    37
#          2008                 Toyota    34
#          2003                 Toyota    28
# Camry    2002                 Toyota    27
#          2003                 Toyota    26
# Corolla  2007                 Toyota    25
# ES       2007                 Lexus     25
# Camry    2004                 Toyota    23
# dtype: int64
# ...

# %% [markdown]
# ##### This is to filter for only cars that use "Mnaual" gear type

# %%
gear_type_manual = naija_cars[naija_cars['Gear Type'] == 'Manual']

print(gear_type_manual)
# Out:
#                         Car ID    Price Fuel Type Gear Type        Make  \
# 14    aa8nq9ZiuiVXOMzlxJvdOPUK  3990000    Diesel    Manual      Lancia
# 51    1K63Licze875g8i1fj53b6Gu  6300000    Petrol    Manual      Toyota
# 64    uJP6DFml83zB3qnkPYQUZhqv  5250000    Petrol    Manual     Hyundai
# 72    5czUputP1RHEgLGuCjntdtBQ  8984000    Petrol    Manual      Toyota
# 157   sKQAqpJ4bfMLCJQqumhQF6sf  5250000    Petrol    Manual      Toyota
# ...                        ...      ...       ...       ...         ...
# 3680  rNY2ef9xuQ3k1wgPbfD0AaUr  1155000    Petrol    Manual  Volkswagen
# 3688  pOrWfzM9aCgdfRBu9LmHPj5O  1575000    Petrol    Manual     Hyundai
# 3695  oGQF1I4eKs2qAWgAP4e1iPG4  1522500    Petrol    Manual     Hyundai
# 3696  pOrWfzM9aCgdfRBu9LmHPj5O  1575000    Petrol    Manual     Hyundai
# 3697  iUiRoEwv8zsxP5tnmKiWlwQs  1270000    Petrol    Manual  Volkswagen
#
#                    Model  Year of manufacture  Colour      Condition  \
# ...

# %% [markdown]
# ##### This is to get the number of each vehicle make and model that uses manual gear type

# %%
count_manual_gear_type = gear_type_manual[
    {
        'Make',
        'Model',
        'Year of manufacture'
    }
].value_counts()

print(count_manual_gear_type)
# Out:
# Model          Year of manufacture  Make
# Hilux          2014                 Toyota        4
# 307            2008                 Peugeot       4
# Corolla        2008                 Toyota        4
# 407            2005                 Peugeot       4
# Corolla        2010                 Toyota        4
#                                                  ..
# Corolla Verso  2002                 Toyota        1
# Corolla        2012                 Toyota        1
#                2000                 Toyota        1
# Condor         2005                 Toyota        1
# Golf           1997                 Volkswagen    1
# Length: 140, dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_2040\832366784.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   count_manual_gear_type = gear_type_manual[

# %% [markdown]
# ##### This is to filter for only cars that use "CVT" gear type

# %%
gear_type_CVT = naija_cars[naija_cars['Gear Type'] == 'CVT']

print(gear_type_CVT)
# Out:
#                         Car ID    Price Fuel Type Gear Type        Make  \
# 118   s4d8VC44VpXroXYz4lKXtpLn  7350000    Petrol       CVT      Toyota
# 185   kSVGq6E4UqCNuiATtX9v2mg3  6825000    Hybrid       CVT      Toyota
# 280   3PP4B7NW8oaR3G56ZIavZd4s  3675000    Hybrid       CVT       Lexus
# 292   mZOf7T6JANdRHlpq9pHWLgMq  4515000    Petrol       CVT      Toyota
# 453   aqOWN8T2zw6ExCWfxMcQ8sVl  6825000    Petrol       CVT      Toyota
# 489   aqOWN8T2zw6ExCWfxMcQ8sVl  6825000    Petrol       CVT      Toyota
# 519   kkGVPpwuXxkVGXBrnUUcX8rR  3150000    Hybrid       CVT      Toyota
# 524   eSugjlvTF0WushdLZBvkF6k5  4095000    Petrol       CVT      Nissan
# 574   kkGVPpwuXxkVGXBrnUUcX8rR  3150000    Hybrid       CVT      Toyota
# 586    IGQgSKeXPJsJoTD2TLPzvEu  5250000    Petrol       CVT      Nissan
# 608    IGQgSKeXPJsJoTD2TLPzvEu  5250000    Petrol       CVT      Nissan
# 617   xoeAIfwM4rIUQehv7mLT9rJz  3150000    Petrol       CVT      Nissan
# ...

# %% [markdown]
# ##### This is to get the number of each vehicle make and model that uses CVT gear type

# %%
count_CVT_gear_type = gear_type_CVT[
    {
        'Make',
        'Model',
        'Year of manufacture'
    }
].value_counts()

print(count_CVT_gear_type)
# Out:
# Model       Year of manufacture  Make
# Pathfinder  2013                 Nissan        3
# Accord      2013                 Honda         2
# Qashqai     2013                 Nissan        2
# Camry       2008                 Toyota        2
#             2011                 Toyota        2
#             2012                 Toyota        2
# Murano      2011                 Nissan        2
# Maxima      2012                 Nissan        2
# Juke        2011                 Nissan        1
# RX          2007                 Lexus         1
# Passat      2006                 Volkswagen    1
# Murano      2009                 Nissan        1
# Maxima      2010                 Nissan        1
# Highlander  2008                 Toyota        1
# Jazz        2005                 Honda         1
# Altima      2010                 Nissan        1
# GS          2005                 Lexus         1
# Corolla     2015                 Toyota        1
# ...

# %%
naija_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3713 entries, 0 to 3721
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Car ID               3713 non-null   object
#  1   Price                3713 non-null   int64
#  2   Fuel Type            3713 non-null   object
#  3   Gear Type            3713 non-null   object
#  4   Make                 3713 non-null   object
#  5   Model                3713 non-null   object
#  6   Year of manufacture  3713 non-null   int64
#  7   Colour               3713 non-null   object
#  8   Condition            3713 non-null   object
#  9   Mileage              3713 non-null   float64
#  10  Engine Size          3713 non-null   float64
#  11  Selling Condition    3713 non-null   object
#  12  Bought Condition     3713 non-null   object
#  13  Car                  3713 non-null   object
#  14  Registered city      3713 non-null   object
# ...

# %%
naija_cars.head(10)
# Out:
#                      Car ID     Price Fuel Type  Gear Type           Make  \
# 0  icwAaDOmX573WiRRnLFPT237   2812500    Petrol  Automatic         Toyota
# 1  ByZ3NlPy2x0arAIyrKazClUS   5000000    Petrol  Automatic          Acura
# 2  2zG6Mh3kwyoTvWoeKHkV1oFH   7592000    Petrol  Automatic          Acura
# 3  7APLHOPlI93qsYK0ST4D4wB2   9880000    Petrol  Automatic     Land Rover
# 4   zIrIDPJLd46eRQf9JFacc0e   4160000    Petrol  Automatic           Ford
# 5  cXCDdlfYhkTgnpxVlSqsiBWz   5250000    Petrol  Automatic          Acura
# 6  3Lh1di00mSJudNaHWxOrn1L2  16640000    Petrol  Automatic          Lexus
# 7  7ytxLUCMQ5bWIly5x5EOrMdG   7980000    Petrol  Automatic          Lexus
# 8  fYxBktHsYw4js3ZgJnHwl2zU   3885000    Petrol  Automatic         Toyota
# 9  oGK8lzkToaZZz9BklAkx1ull  13000000    Petrol  Automatic  Mercedes-Benz
#
#          Model  Year of manufacture  Colour      Condition   Mileage  \
# 0      Corolla                 2004  Silver  Nigerian Used  251732.0
# ...

# %% [markdown]
# ### Most popular car brands
#
# This analysis aims at revealing the most popular car brands in Nigeria based on the frequency of occurrence in the dataset.

# %% [markdown]
# **For Car Make**

# %%
for_most_popular_make = naija_cars[
    {
        'Make',
        'Model',
        #'Year of manufacture',
        #'Price'
    }
].value_counts()

pd.set_option('display.max_rows', None)

print(for_most_popular_make.sort_values( ascending = False, inplace=True))
# Out:
# None
# C:\Users\USER\AppData\Local\Temp\ipykernel_2040\3402251616.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   for_most_popular_make = naija_cars[

# %% [markdown]
# **This shows the 20 most popular car make based on the number of of individuals that own them**

# %%
for_most_popular_make
# Out:
# Model               Price     Make
# Camry               4680000   Toyota           29
#                     3120000   Toyota           27
#                     2080000   Toyota           23
# Corolla             3640000   Toyota           23
# Camry               2625000   Toyota           23
# Corolla             2100000   Toyota           19
# Camry               2912000   Toyota           17
# Corolla             2600000   Toyota           16
# Camry               3328000   Toyota           16
#                     2600000   Toyota           16
# Corolla             2625000   Toyota           15
# Camry               3640000   Toyota           14
#                     3432000   Toyota           13
# Accord              1260000   Honda            13
# ES                  4160000   Lexus            12
# Accord              2600000   Honda            12
# Corolla             2205000   Toyota           12
#                     3120000   Toyota           11
# ...

# %% [markdown]
# **For Car Model**

# %%
for_most_popular_model = naija_cars[
    {
        'Make',
        'Model'
    }
].value_counts()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2040\1174158572.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   for_most_popular_model = naija_cars[

# %% [markdown]
# **This shows the 20 most popular car models based on the number of of individuals that own them**

# %%
for_most_popular_model
# Out:
# Model               Make
# Camry               Toyota           548
# Corolla             Toyota           405
# Accord              Honda            178
# Highlander          Toyota           139
# ES                  Lexus            115
# Sienna              Toyota           103
# RAV4                Toyota            90
# Edge                Ford              77
# RX 350              Lexus             70
# M Class             Mercedes-Benz     53
# Pilot               Honda             53
# Venza               Toyota            50
# MDX                 Acura             50
# C300                Mercedes-Benz     48
# Sonata              Hyundai           47
# Avalon              Toyota            47
# Matrix              Toyota            44
# IS                  Lexus             41
# CR-V                Honda             38
# Civic               Honda             37
# Elantra             Hyundai           33
# GL-Class            Mercedes-Benz     33
# ...

# %% [markdown]
# ### Least popular car brands
#
# This analysis aims at revealing the least popular car brands in Nigeria based on the frequency of occurrence in the dataset.

# %%
for_least_popular_make = naija_cars[
    {
        'Make',
        'Model'
    }
].value_counts()

print(for_least_popular_make.sort_values( ascending = True, inplace=True))
# Out:
# None
# C:\Users\USER\AppData\Local\Temp\ipykernel_2040\1021389580.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   for_least_popular_make = naija_cars[

# %% [markdown]
# #### This shows the 20 least popular cars based on the number of of individuals that own them

# %%
for_least_popular_make.head(30)
# Out:
# Model      Make
# 116i       BMW              1
# Vitara     Suzuki           1
# Viano      Mercedes-Benz    1
# 7 Series   BMW              1
# Veracruz   Hyundai          1
# 807        Peugeot          1
# A6         Audi             1
# Vectra     Opel             1
# Vamos      Honda            1
# Uplander   Chevrolet        1
# Canter     Mitsubishi       1
# 550i       BMW              1
# Tribute    Mazda            1
# Touareg    Volkswagen       1
# Avenger    Dodge            1
# Acadia     GMC              1
# Commander  Jeep             1
# Carens     Kia              1
# Polo       Volkswagen       1
# Pick-Up    Nissan           1
# GLC-Class  Mercedes-Benz    1
# GLS-Class  Mercedes-Benz    1
# Panamera   Porsche          1
# Tribeca    Subaru           1
# 523i       BMW              1
# 508        Peugeot          1
# 5 Series   BMW              1
# Bora       Volkswagen       1
# Stream     Honda            1
# Teana      Nissan           1
# dtype: int64

# %% [markdown]
# ### Body Type Trends and Car Make
#
# This analysis shows the trends in car make and body type in Nigeria over time.
#
# It can reveal which car brands and body types are becoming more popular and which are losing their popularity.

# %%
unique_car_body_type = naija_cars['Car'].unique()

print(unique_car_body_type)
# Out:
# ['Not Provided' 'SUV' 'Sedan' 'Truck' 'Crossover' 'Van' 'Bus' 'Coupe'
#  'Hatchback' 'Minivan' 'Pickup' 'Convertible' 'Station Wagon'
#  'Pick-up Double Cabin' 'MUV' 'Saloon']

# %% [markdown]
# #### Number of vehicles present in each category of car body type

# %%
naija_cars['Car'].value_counts()
# Out:
# Not Provided            1952
# SUV                     1137
# Sedan                    383
# Truck                     44
# Hatchback                 42
# Minivan                   35
# Coupe                     33
# Crossover                 23
# Bus                       15
# Van                       12
# Pickup                     9
# Station Wagon              8
# Convertible                6
# Saloon                     6
# MUV                        5
# Pick-up Double Cabin       3
# Name: Car, dtype: int64

# %% [markdown]
# ##### For SUVS

# %%
car_suv = naija_cars[naija_cars['Car'] == 'SUV']

print(car_suv)
# Out:
#                         Car ID     Price Fuel Type  Gear Type           Make  \
# 1     ByZ3NlPy2x0arAIyrKazClUS   5000000    Petrol  Automatic          Acura
# 3     7APLHOPlI93qsYK0ST4D4wB2   9880000    Petrol  Automatic     Land Rover
# 4      zIrIDPJLd46eRQf9JFacc0e   4160000    Petrol  Automatic           Ford
# 5     cXCDdlfYhkTgnpxVlSqsiBWz   5250000    Petrol  Automatic          Acura
# 6     3Lh1di00mSJudNaHWxOrn1L2  16640000    Petrol  Automatic          Lexus
# ...                        ...       ...       ...        ...            ...
# 3708  zXmEzjImIELlVgTXh3kstPbT   2100000    Petrol  Automatic            Kia
# 3713  wPxnfFvxyLtzDhgkrLudZ9UH   3848000    Petrol  Automatic            Kia
# 3717  C4Ly76wwazrtbYRAWkTnv2Q5   1924000    Petrol  Automatic         Toyota
# 3718  jPA7XlJJxdwpZStlurumw59q   1890000    Petrol  Automatic  Mercedes-Benz
# 3720  mdZMNQK7Zez0cSS67Q9Quhzr   1260000    Petrol  Automatic         Toyota
#
# ...

# %%
car_suv[
    {
        'Car',
        'Make',
        'Model',
        'Year of manufacture'
    }
].value_counts()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2040\3162250114.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   car_suv[
# Model       Car  Year of manufacture  Make
# Highlander  SUV  2008                 Toyota           21
# Venza       SUV  2010                 Toyota           16
# RAV4        SUV  2008                 Toyota           16
# GL-Class    SUV  2007                 Mercedes-Benz    13
# RX 350      SUV  2007                 Lexus            13
#                                                        ..
# MDX         SUV  2005                 Acura             1
#                  2006                 Acura             1
#                  2010                 Acura             1
#                  2011                 Acura             1
# Zafira      SUV  2002                 Opel              1
# Length: 435, dtype: int64

# %%
car_suv[
    {
        'Car',
        'Make'

    }
].value_counts()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2040\3003730818.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   car_suv[
# Car  Make
# SUV  Toyota           331
#      Lexus            151
#      Mercedes-Benz    113
#      Ford             103
#      Honda             94
#      Nissan            48
#      Acura             46
#      Hyundai           44
#      Land Rover        41
#      Mazda             23
#      Mitsubishi        22
#      Infiniti          21
#      Kia               19
#      BMW               14
#      Jeep              10
#      Volvo              7
#      Volkswagen         7
#      Dodge              6
#      Pontiac            4
#      Cadillac           4
#      Audi               3
#      Chevrolet          3
#      Porsche            3
#      Renault            3
#      GMC                3
#      Lincoln            2
#      Chrysler           2
#      Mercury            2
# ...

# %% [markdown]
# ##### For Sedan Vehicles

# %%
car_sedan = naija_cars[naija_cars['Car'] == 'Sedan']

print(car_sedan)
# Out:
#                         Car ID     Price Fuel Type  Gear Type        Make  \
# 2     2zG6Mh3kwyoTvWoeKHkV1oFH   7592000    Petrol  Automatic       Acura
# 7     7ytxLUCMQ5bWIly5x5EOrMdG   7980000    Petrol  Automatic       Lexus
# 17    uzW7BZeKaIdBbBdrjCFG4hto  13520000    Petrol  Automatic      Toyota
# 30    CzA8eoAXw33mrIRa6aozRCG7   4576000    Petrol  Automatic      Toyota
# 39    wtFHr0JNVp2vJpOGzDwHsf8B  10080000    Petrol  Automatic       Lexus
# ...                        ...       ...       ...        ...         ...
# 3666  dcNJZ22G6Hw5pwtD1NpR3BlW   2205000    Petrol  Automatic     Hyundai
# 3672  CypE2IwZhS6oBIqgNez2PMRH   1785000    Petrol  Automatic  Volkswagen
# 3695  oGQF1I4eKs2qAWgAP4e1iPG4   1522500    Petrol     Manual     Hyundai
# 3710  58YCyUCEzwn1f3ej2S5N9DoA   2080000    Petrol  Automatic       Honda
# 3719  g5szhuHeXu2djH1Z2be22G7E   1155000    Petrol  Automatic      Toyota
#
#         Model  Year of manufacture  Colour      Condition   Mileage  \
# ...

# %%
car_sedan[
    {
        'Make',
        'Car',
        'Model',
        'Year of manufacture'
    }
].value_counts()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2040\3668630357.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   car_sedan[
# Model    Car    Year of manufacture  Make
# Camry    Sedan  2007                 Toyota    19
#                 2012                 Toyota    18
#                 2009                 Toyota    14
# Corolla  Sedan  2004                 Toyota    12
# ES       Sedan  2007                 Lexus     12
#                                                ..
# Civic    Sedan  2012                 Honda      1
#                 2008                 Honda      1
#                 2000                 Honda      1
# Charger  Sedan  2016                 Dodge      1
# XJ       Sedan  2013                 Jaguar     1
# Length: 136, dtype: int64

# %%
naija_cars.head(4)
# Out:
#                      Car ID    Price Fuel Type  Gear Type        Make  \
# 0  icwAaDOmX573WiRRnLFPT237  2812500    Petrol  Automatic      Toyota
# 1  ByZ3NlPy2x0arAIyrKazClUS  5000000    Petrol  Automatic       Acura
# 2  2zG6Mh3kwyoTvWoeKHkV1oFH  7592000    Petrol  Automatic       Acura
# 3  7APLHOPlI93qsYK0ST4D4wB2  9880000    Petrol  Automatic  Land Rover
#
#          Model  Year of manufacture  Colour      Condition   Mileage  \
# 0      Corolla                 2004  Silver  Nigerian Used  251732.0
# 1          MDX                 2007   Green   Foreign Used  224589.0
# 2           TL                 2012   White   Foreign Used  111334.0
# 3  Range Rover                 2012    Gray  Nigerian Used   72682.0
#
#    Engine Size Selling Condition Bought Condition           Car  \
# 0       1800.0        Registered       Registered  Not Provided
# 1       3700.0          Imported         Imported           SUV
# 2       3500.0          Imported         Imported         Sedan
# ...

# %% [markdown]
# ####

# %% [markdown]
# ### Car Condition

# %% [markdown]
# ##### Create a statement to provide the unique values in the "Condition Column"

# %%
unique_car_condition = naija_cars['Condition'].unique()

print(unique_car_condition)
# Out:
# ['Nigerian Used' 'Foreign Used' 'Brand New']

# %% [markdown]
# ##### Get the number of vehicles present in each car condition

# %%
naija_cars['Condition'].value_counts()
# Out:
# Nigerian Used    2805
# Foreign Used      906
# Brand New           2
# Name: Condition, dtype: int64

# %% [markdown]
# ##### Get the most common vehicles in each car condition

# %% [markdown]
# **For Nigerian Used Vehicles**

# %%
condition_nigerian_used = naija_cars[naija_cars['Condition'] == 'Nigerian Used']

print(condition_nigerian_used)
# Out:
#                         Car ID     Price Fuel Type  Gear Type           Make  \
# 0     icwAaDOmX573WiRRnLFPT237   2812500    Petrol  Automatic         Toyota
# 3     7APLHOPlI93qsYK0ST4D4wB2   9880000    Petrol  Automatic     Land Rover
# 4      zIrIDPJLd46eRQf9JFacc0e   4160000    Petrol  Automatic           Ford
# 5     cXCDdlfYhkTgnpxVlSqsiBWz   5250000    Petrol  Automatic          Acura
# 6     3Lh1di00mSJudNaHWxOrn1L2  16640000    Petrol  Automatic          Lexus
# ...                        ...       ...       ...        ...            ...
# 3717  C4Ly76wwazrtbYRAWkTnv2Q5   1924000    Petrol  Automatic         Toyota
# 3718  jPA7XlJJxdwpZStlurumw59q   1890000    Petrol  Automatic  Mercedes-Benz
# 3719  g5szhuHeXu2djH1Z2be22G7E   1155000    Petrol  Automatic         Toyota
# 3720  mdZMNQK7Zez0cSS67Q9Quhzr   1260000    Petrol  Automatic         Toyota
# 3721  fSUvulLwnXYlc1muFsrjrsAR   1872000    Petrol  Automatic          Honda
#
# ...

# %%
nigerian_used = condition_nigerian_used[
    {
        'Make',
        'Model',
        #'Year of manufacture'
        #'Registered city'
    }
].value_counts()

# To display all rows
pd.set_option('display.max_rows', None)

print(nigerian_used)

#nigerian_used_df = nigerian_used.to_frame()
#print(nigerian_used_df.head(len(nigerian_used_df)))
# Out:
# Model               Make
# Camry               Toyota           408
# Corolla             Toyota           318
# Accord              Honda            165
# Highlander          Toyota           102
# ES                  Lexus             78
# RAV4                Toyota            75
# Sienna              Toyota            67
# Edge                Ford              60
# Avalon              Toyota            42
# RX 350              Lexus             39
# M Class             Mercedes-Benz     37
# MDX                 Acura             35
# Venza               Toyota            35
# Civic               Honda             34
# Matrix              Toyota            33
# Pilot               Honda             33
# CR-V                Honda             33
# Sonata              Hyundai           32
# GL-Class            Mercedes-Benz     30
# IS                  Lexus             30
# C300                Mercedes-Benz     29
# Elantra             Hyundai           28
# ...

# %% [markdown]
# **For Foreign Used Vehicles**

# %%
condition_foreign_used = naija_cars[naija_cars['Condition'] == 'Foreign Used']

print(condition_foreign_used)
# Out:
#                         Car ID     Price Fuel Type  Gear Type           Make  \
# 1     ByZ3NlPy2x0arAIyrKazClUS   5000000    Petrol  Automatic          Acura
# 2     2zG6Mh3kwyoTvWoeKHkV1oFH   7592000    Petrol  Automatic          Acura
# 8     fYxBktHsYw4js3ZgJnHwl2zU   3885000    Petrol  Automatic         Toyota
# 9     oGK8lzkToaZZz9BklAkx1ull  13000000    Petrol  Automatic  Mercedes-Benz
# 11    8Zxki4qLpwloj8iR2vPf2DIU  14560000    Petrol  Automatic  Mercedes-Benz
# ...                        ...       ...       ...        ...            ...
# 3690  b7k6XMqUeGcIFRXFatvrEYmM   3675000    Petrol  Automatic         Toyota
# 3692  CdGEo0i0Y8nSwxTU4dbrkiZX   2415000    Petrol  Automatic  Mercedes-Benz
# 3697  iUiRoEwv8zsxP5tnmKiWlwQs   1270000    Petrol     Manual     Volkswagen
# 3698  b7k6XMqUeGcIFRXFatvrEYmM   3675000    Petrol  Automatic         Toyota
# 3704  yXJHinXZ31cNc1PSj7GJJIi9   2100000    Petrol  Automatic         Toyota
#
# ...

# %%
foreign_used = condition_foreign_used[
    {
        'Make',
        'Model',
        'Year of manufacture',
    }
].value_counts()

pd.set_option('display.max_rows', None)

print(foreign_used)
# Out:
# Model               Year of manufacture  Make
# Camry               2012                 Toyota           19
#                     2011                 Toyota           18
#                     2010                 Toyota           18
#                     2007                 Toyota           17
#                     2009                 Toyota           14
# Corolla             2010                 Toyota           13
# Camry               2005                 Toyota           11
# Corolla             2007                 Toyota           10
#                     2009                 Toyota            9
# Camry               2008                 Toyota            9
# Corolla             2005                 Toyota            8
# Camry               2014                 Toyota            8
# ES                  2007                 Lexus             8
# Venza               2010                 Toyota            7
# Corolla             2011                 Toyota            7
# ...

# %% [markdown]
# **For Brand New Vehicles**

# %%
condition_brand_new = naija_cars[naija_cars['Condition'] == 'Brand New']

# %%
condition_brand_new[
    {
        'Make',
        'Model',
        'Year of manufacture',
        'Registered city'
    }
]
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2040\2645188340.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   condition_brand_new[
#      Registered city    Model  Year of manufacture        Make
# 706     Not Provided  Corolla                 2012      Toyota
# 3053    Not Provided   Pajero                 2014  Mitsubishi

# %%
brand_new = condition_brand_new[
    {
        'Make',
        'Model',
        #'Year of manufacture'
    }
].value_counts()

print(brand_new)
# Out:
# Model    Make
# Corolla  Toyota        1
# Pajero   Mitsubishi    1
# dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_2040\844369652.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   brand_new = condition_brand_new[

# %% [markdown]
# ## Extraction

# %% [markdown]
# #### Here, I will extract the different datasets into an excel file for Microsoft Power BI

# %% [markdown]
# **For Price Distribution of Different Car Makes**

# %%
fuel_type = Counter(naija_cars['Fuel Type'])

# %%
fuel_type_table = pd.DataFrame.from_dict(fuel_type, orient='index', columns=['Count'])

fuel_type_table("Fuel Type Table", sheet_name= 'Fuel Type Counts')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2040\1854895978.py in <module>
#       1 fuel_type_table = pd.DataFrame.from_dict(fuel_type, orient='index', columns=['Count'])
#       2
# ----> 3 fuel_type_table("Fuel Type Table", sheet_name= 'Fuel Type Counts')
#
# TypeError: 'DataFrame' object is not callable

# %%
with pd.ExcelWriter('Nigerian Cars Analysis.xlsx') as writer:
    max_for_price_variation.head(10).to_excel(writer, sheet_name='Most Expensive Cars')
    min_for_price_variation.head(10).to_excel(writer, sheet_name='Least Expensive Cars')
    foreign_used.tolist
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2040\3373846780.py in <module>
# ----> 1 with pd.ExcelWriter('Nigerian Cars Analysis.xlsx') as writer:
#       2     max_for_price_variation.head(10).to_excel(writer, sheet_name='Most Expensive Cars')
#       3     min_for_price_variation.head(10).to_excel(writer, sheet_name='Least Expensive Cars')
#
# c:\Users\USER\anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     189             raise ValueError("Append mode is not supported with xlsxwriter!")
#     190
# --> 191         super().__init__(
#     192             path,
#     193             engine=engine,
#
# ...
